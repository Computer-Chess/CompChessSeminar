# %%
import pieces
import numpy as np
from utils import get_control_heatmap, plot_heatmap

# %%
# %matplotlib inline

# %% [markdown]
# **Parameters**:

# %%
NROWS, NCOLS = 8, 8
TWEAKS = {'cmap': 'Greys', 'figsize': (8, 7), 'vmin': 0, 'vmax': 27}

# %% [markdown]
# ### Queen

# %%
heatmap_queen = get_control_heatmap(pieces.Queen, NROWS, NCOLS)

# %%
plot_heatmap(heatmap_queen, title='QUEEN (avg. = {})'.format(heatmap_queen.mean()), **TWEAKS)

# %% [markdown]
# ### Knight

# %%
heatmap_knight = get_control_heatmap(pieces.Knight, NROWS, NCOLS)

# %%
plot_heatmap(heatmap_knight, title='KNIGHT (avg. = {})'.format(heatmap_knight.mean()), **TWEAKS)

# %% [markdown]
# ### Bishop

# %%
heatmap_bishop = get_control_heatmap(pieces.Bishop, NROWS, NCOLS)

# %%
plot_heatmap(heatmap_bishop, title='BISHOP (avg. = {})'.format(heatmap_bishop.mean()), **TWEAKS)

# %% [markdown]
# ### Rook

# %%
heatmap_rook = get_control_heatmap(pieces.Rook, NROWS, NCOLS)

# %%
plot_heatmap(heatmap_rook, title='ROOK (avg. = {})'.format(heatmap_rook.mean()), **TWEAKS)

# %% [markdown]
# ### King

# %%
heatmap_king = get_control_heatmap(pieces.King, NROWS, NCOLS)

# %%
plot_heatmap(heatmap_king, title='KING (avg. = {})'.format(heatmap_king.mean()), **TWEAKS)
